# %% [markdown]
# # CSE 6369 - Spring 2023 - Homework 1
#
#
# ## Student Name:
#
#
# ## Student ID:

# %% [markdown]
# # Install packages

# %%
# !pip install gymnasium==0.27.1 -q
# !pip install gymnasium[box2d] -q
# !pip install moviepy -q
# !pip install -U kora -q
# Out:
# zsh:1: no matches found: gymnasium[box2d]

# %% [markdown]
# # Import libraries

# %%
import pickle
import random
import argparse
import moviepy
import matplotlib.pyplot as plt
import seaborn as sns
# from kora.drive import upload_public
# from google.colab import drive

# drive.mount('/content/gdrive')
# %cd gdrive/MyDrive/assign_01/

from learning_algorithms import PGTrainer
from utils import seed_everything

# %% [markdown]
# # Train an agent

# %%
# set simulation parameters
params = {
    'env_name': 'CartPole-v1',
    'rng_seed': 6369,
    'reward_to_go': True,
    'reward_discount': False,
    'n_rollout': 100,
    'n_trajectory_per_rollout': 10,
    'hidden_dim': 32,
    'lr': 3e-3,
    'exp_name': 'CartPole_v1_t0'
}

# Seed RNGs
seed_everything(params['rng_seed'])

# Train agent
trainer = PGTrainer(params)
trainer.run_training_loop()
# Out:
# End of rollout 0: Average trajectory reward is  71.00
# End of rollout 1: Average trajectory reward is  49.00
# End of rollout 2: Average trajectory reward is  27.00
# End of rollout 3: Average trajectory reward is  55.00
# End of rollout 4: Average trajectory reward is  95.00
# End of rollout 5: Average trajectory reward is  29.00
# End of rollout 6: Average trajectory reward is  37.00
# End of rollout 7: Average trajectory reward is  40.00
# End of rollout 8: Average trajectory reward is  59.00
# End of rollout 9: Average trajectory reward is  46.00
# Moviepy - Building video /Users/krishnakhadka/Desktop/cse6369_spring2023-main/hw1/python/CartPole/rl-video-episode-0.mp4.
# Moviepy - Writing video /Users/krishnakhadka/Desktop/cse6369_spring2023-main/hw1/python/CartPole/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /Users/krishnakhadka/Desktop/cse6369_spring2023-main/hw1/python/CartPole/rl-video-episode-0.mp4

# %% [markdown]
# # Display Video

# %%
# (ref: https://stackoverflow.com/questions/48376580/google-colab-how-to-read-data-from-my-google-drive)
# Upload video
url = upload_public('CartPole/rl-video-episode-0.mp4')
# Then display it
from IPython.display import HTML
HTML(f"""<video src={url} width=500 controls/>""")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # (ref: https://stackoverflow.com/questions/48376580/google-colab-how-to-read-data-from-my-google-drive)
#       2 # Upload video
# ----> 3 url = upload_public('CartPole/rl-video-episode-0.mp4')
#       4 # Then display it
#       5 from IPython.display import HTML
#
# NameError: name 'upload_public' is not defined

# %% [markdown]
# # Visualize learning curve

# %%
# (ref: http://rail.eecs.berkeley.edu/deeprlcourse/static/misc/viz.pdf)
file_name = params['exp_name'] + '.pkl'
with open(file_name, 'rb') as f:
    ro_reward = pickle.load(f)

# Plot the data
sns.lineplot(data=ro_reward, linestyle='--', label='tr1')
plt.xlabel('rollout', fontsize=25, labelpad=-2)
plt.ylabel('reward', fontsize=25)
plt.title('Learning curve for CartPole', fontsize=30)
plt.legend()
plt.grid()
plt.show()
